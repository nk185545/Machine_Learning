# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snsmissing_val_per=df.isnull().sum()/df.shape[0]*100
missing_val_per

# %%
df=pd.read_csv("train.csv")

# %%
df.shape
# Out:
# (1460, 81)

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
missing_val_per=df.isnull().sum()/df.shape[0]*100
missing_val_per
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.547945
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# ...

# %%
missing_val_gre_20=missing_val_per[missing_val_per >20].keys()
missing_val_gre_20
# Out:
# Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
df2_drop_col=df.drop(columns=missing_val_gre_20) 
df2_drop_col.shape
# Out:
# (1460, 76)

# %%
df3_num=df2_drop_col.select_dtypes(include=['int64','float64'])
df3_num.head(8)
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
# 5   6          50         85.0    14115            5            5       1993
# 6   7          20         75.0    10084            8            5       2004
# 7   8          60          NaN    10382            7            6       1973
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# ...

# %%
df3_num.shape
# Out:
# (1460, 38)

# %%
df3_num.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
df3_num[df3_num.isnull().any(axis=1)]
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 7        8          60          NaN    10382            7            6
# 12      13          20          NaN    12968            5            6
# 14      15          20          NaN    10920            6            5
# 16      17          20          NaN    11241            6            7
# 24      25          20          NaN     8246            5            8
# 31      32          20          NaN     8544            5            6
# 39      40          90         65.0     6040            4            5
# 42      43          85          NaN     9180            5            7
# 43      44          20          NaN     9200            5            6
# 48      49         190         33.0     4456            4            5
# 50      51          60          NaN    13869            6            6
# 64      65          60          NaN     9375            7            5
# ...

# %%
df['LotConfig'].unique()
# Out:
# array(['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3'], dtype=object)

# %%
df[df.loc[:,'LotConfig']=='Inside']['LotFrontage']
# Out:
# 0        65.0
# 2        68.0
# 5        85.0
# 6        75.0
# 8        51.0
# 10       70.0
# 11       85.0
# 12        NaN
# 13       91.0
# 17       72.0
# 18       66.0
# 19       70.0
# 21       57.0
# 22       75.0
# 23       44.0
# 24        NaN
# 27       98.0
# 29       60.0
# 30       50.0
# 33       70.0
# 34       60.0
# 35      108.0
# 37       74.0
# 38       68.0
# 39       65.0
# 40       84.0
# 41      115.0
# 44       70.0
# 45       61.0
# 47       84.0
# 48       33.0
# 49       66.0
# 51       52.0
# 53       68.0
# 54       60.0
# 55      100.0
# 56       24.0
# 59       60.0
# 60       63.0
# 61       60.0
# 62       44.0
# 63       50.0
# 64        NaN
# 65       76.0
# 66        NaN
# 67       72.0
# 70       95.0
# 73       85.0
# 75       21.0
# 76        NaN
# 77       50.0
# 78       72.0
# 82       78.0
# 83       80.0
# 84        NaN
# 86      122.0
# 89       60.0
# 90       60.0
# 91       85.0
# 92       80.0
# 94       69.0
# 96       78.0
# ...

# %%
df[df.loc[:,'LotConfig']=='Inside']['LotFrontage'].replace(np.nan,df[df.loc[:,'LotConfig']=='Inside']['LotFrontage'].mean())
# Out:
#   File "<ipython-input-29-f2e229503865>", line 1
#     df[df.loc[:,'LotConfig']==var]['LotFrontage'].replace(np.nan,df[df.loc[:,'LotConfig']=='var]['LotFrontage'].mean())
#                                                                                                   ^
# SyntaxError: invalid syntax

# %%
df_copy=df.copy()
for var in df['LotConfig'].unique():
    
    df_copy.update(df[df.loc[:,'LotConfig']==var]['LotFrontage'].replace(np.nan,df[df.loc[:,'LotConfig']==var]['LotFrontage'].mean()))

# %% [markdown]
# df_copy.isnull().sum()

# %%
df_copy=df.copy()
num_miss_val=['LotFrontage','GarageYrBlt','MasVnrArea']
cat_var=['LotConfig','GarageType','MasVnrType']
for cat_var,num_miss_val in zip(cat_var,num_miss_val):
 
    for var in df[cat_var].unique():
    
        df_copy.update(df[df.loc[:,cat_var]==var][num_miss_val].replace(np.nan,df[df.loc[:,cat_var]==var][num_miss_val].mean()))

# %%
df_copy[num_miss_val].isnull().sum()
# Out:
# 8

# %%
df_copy[df_copy[['MasVnrArea']].isnull().any(axis=1)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 234    235          60       RL    67.715686     7851   Pave   NaN      Reg
# 529    530          20       RL    59.911111    32668   Pave   NaN      IR1
# 650    651          60       FV    65.000000     8125   Pave   NaN      Reg
# 936    937          20       RL    67.000000    10083   Pave   NaN      Reg
# 973    974          20       FV    95.000000    11639   Pave   NaN      Reg
# 977    978         120       FV    35.000000     4274   Pave  Pave      IR1
# 1243  1244          20       RL   107.000000    13891   Pave   NaN      Reg
# 1278  1279          60       RL    75.000000     9473   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 234          Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 529          Lvl    AllPub   CulDSac       Gtl      Crawfor       Norm
# ...

# %%
df_copy[df_copy[['GarageType']].isnull().any(axis=1)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 39      40          90       RL    65.000000     6040   Pave   NaN      Reg
# 48      49         190       RM    33.000000     4456   Pave   NaN      Reg
# 78      79          90       RL    72.000000    10778   Pave   NaN      Reg
# 88      89          50  C (all)   105.000000     8470   Pave   NaN      IR1
# 89      90          20       RL    60.000000     8070   Pave   NaN      Reg
# 99     100          20       RL    77.000000     9320   Pave   NaN      IR1
# 108    109          50       RM    85.000000     8500   Pave   NaN      Reg
# 125    126         190       RM    60.000000     6780   Pave   NaN      Reg
# 127    128          45       RM    55.000000     4388   Pave   NaN      IR1
# 140    141          20       RL    70.000000    10500   Pave   NaN      Reg
# 148    149          20       RL    63.000000     7500   Pave   NaN      Reg
# ...
